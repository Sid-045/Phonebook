# %% [markdown]
# <a href="https://colab.research.google.com/github/Sid-045/Phonebook/blob/main/Movie_tickets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo[srv]
# !pip install dnspython
# !pip install pillow
# !pip install qrcode

# %%
import pymongo
from pymongo import MongoClient

client = pymongo.MongoClient("mongodb+srv://username:<password>@cluster0.eubig.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.Movie
records= db.personalinfo

# %%
seat=db.seats
new = [{"Movie":"SPIDERMAN","Screen": "S1","Show Time":"11-AM","Seats":50},
       {"Movie":"SPIDERMAN","Screen": "S1","Show Time":"2-PM","Seats":50},
       {"Movie":"SPIDERMAN","Screen": "S1","Show Time":"6-PM","Seats":50},
       {"Movie":"SPIDERMAN","Screen": "S1","Show Time":"9-PM","Seats":50},
       {"Movie":"KGF 2","Screen": "S2","Show Time":"11-AM","Seats":50},
       {"Movie":"KGF 2","Screen": "S2","Show Time":"2-PM","Seats":50},
       {"Movie":"KGF 2","Screen": "S2","Show Time":"6-PM","Seats":50},
       {"Movie":"KGF 2","Screen": "S2","Show Time":"9-PM","Seats":50},
       {"Movie":"PUSHPA","Screen": "S3","Show Time":"11-AM","Seats":50},
       {"Movie":"PUSHPA","Screen": "S3","Show Time":"2-PM","Seats":50},
       {"Movie":"PUSHPA","Screen": "S3","Show Time":"6-PM","Seats":50},
       {"Movie":"PUSHPA","Screen": "S3","Show Time":"9-PM","Seats":50},
       {"Movie":"VALIMAI","Screen": "S4","Show Time":"11-AM","Seats":50},
       {"Movie":"VALIMAI","Screen": "S4","Show Time":"2-PM","Seats":50},
       {"Movie":"VALIMAI","Screen": "S4","Show Time":"6-PM","Seats":50},
       {"Movie":"VALIMAI","Screen": "S4","Show Time":"9-PM","Seats":50},
       {"Movie":"BEAST","Screen": "S5","Show Time":"11-AM","Seats":50},
       {"Movie":"BEAST","Screen": "S5","Show Time":"2-PM","Seats":50},
       {"Movie":"BEAST","Screen": "S5","Show Time":"6-PM","Seats":50},
       {"Movie":"BEAST","Screen": "S5","Show Time":"9-PM","Seats":50},
       ]
seat.insert_many(new)

# %%
import pandas as pd
import re
regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'

# %%
def newuser():
  global emai
  email= input("Enter email-id :- ")
  if (re.fullmatch(regex, email)):
    emai= email
    pas()      
  else:
    print("Invalid Email-enter new Emailid")
    newuser()

def pas():
  global pa
  password = input("Enter password :- ")
  if len(password)<8:
    print("Entered password is too short - reenter password")
    pas()
  elif len(password)>12:
    print("Entered password is too long - reenter password")
    pas()
  else:
    pa=password

def phonenumber():
  global p
  phone=input("Enter 10-digit phone number :- ")
  if len(phone)!=10:
    print("Invalid phone number - reenter phone number")
    phonenumber()
  else:
    p= phone

def existing(email):
  password = input("Enter password :- ")
  y=0
  for x in records.find({"Email-id": email},{"Password":1}):
    y=x["Password"]
  if y==0:
    print("No results found - Please register first to book tickets")
    newuser()
    phonenumber()
    fname=input("Enter first name :- ")
    Lname=input("Enter Last name :- ")
    name = fname+" "+Lname
    print(emai,p,pa,name)
    info={"Name":name,
        "Email-id": emai,
        "Phone Number":p,
        "Password": pa}
    
    records.insert_one(info)
    print("Registration Successful - Please login to book tickets")
    x=input("To login enter y  :- ")
    if x=="y":
      email= input("Enter email-id :- ")
      existing(email)
    
  elif y!= password:
    print("Enteres wrong password - reenter password")
    existing(email)

  elif y==password:
    for x in records.find({"Email-id": email},{"Name":1}):
      y=x["Name"]
    lis.append(email)
    lis.append(y)
    
    print("Login Successful\nYou can proceed to book tickets")

# %%
def movie():
  global e
  global sc
  print('''These are the movies playing in Chennai
          1- Spiderman
          2- KGF 2
          3- Pushpa
          4- Valimai
          5- Beast''')

  num= int(input("Enter the number for the respective movie :-"))
  if num == 1:
    ab= input("You have selected SPIDERMAN movie \nTo continue enter c to return to movie menu enter b :-")
    if ab == "b":
      movie()
    elif ab=="c":
      print('Movie - SPIDERMAN\nIMDB ratings - 8.5\n movie Screen - S1')
      e="SPIDERMAN"
      sc="S1"

  elif num == 2:
    ab= input("You have selected KGF 2 movie \nTo continue enter c to return to movie menu enter b:- ")
    if ab == "b":
      movie()
    elif ab=="c":
      print('Movie - KGF 2\nIMDB ratings - 8.5\n movie Screen - S2')
      e="KGF 2"
      sc="S2"

  elif num == 3:
    ab= input("You have selected PUSHPA movie \nTo continue enter c to return to movie menu enter b :- ")
    if ab == "b":
      movie()
    elif ab=="c":
      print('Movie - PUSHPA\nIMDB ratings - 8.5\n movie Screen - S3')
      e="PUSHPA"
      sc="S3"

  elif num == 4:
    ab= input("You have selected VALIMAI movie \nTo continue enter c to return to movie menu enter b :- ")
    if ab == "b":
      movie()
    elif ab=="c":
      print(' Movie - VALIMAI\nIMDB ratings - 8.5\n movie Screen - S4')
      e="VALIMAI"
      sc="S4"

  elif num == 5:
    ab= input("You have selected BEAST movie \nTo continue enter c to return to movie menu enter b :- ")
    if ab == "b":
      movie()
    elif ab=="c":
      print('Movie - BEAST\nIMDB ratings - 8.5\n movie Screen - S5')
      e="BEAST"
      sc="S5"

# %%
def book():
  global seatss
  global showt
  l1=[]
  for x in seat.find({"Movie":e},{"_id":0,"Show Time":1,"Seats":1}):
    l1.append(x)
  z=pd.DataFrame(l1)
  print(z)
  y=input("Enter Showtime : ")
  if y == "11-AM":
    showt=y
    for x in seat.find({"Movie":e,"Show Time":"11-AM"},{"_id":0,"Seats":1}):
      z=x["Seats"]
      print("Available seats :- ",z)
    req= int(input("Enter number of seats(one user cannot book more than 5 books) :- "))
    if req>5:
      print("One user cannotbook more than 5 seats")
      req= int(input("Enter number of seats:- "))
    seatnumbers=[]
    for x in range(req):
      seatnumbers.append(z-x)
    print(seatnumbers)
    seatss=seatnumbers
    seat.update_one({"Movie":e,"Show Time":"11-AM"},{"$inc":{"Seats":-req}})
    for x in seat.find({"Movie":e,"Show Time":"11-AM"},{"_id":0,"Seats":1}):
      z=x["Seats"]
      print("Available seats :- ",z)

  elif y == "2-PM":
    showt=y
    for x in seat.find({"Movie":e,"Show Time":"2-PM"},{"_id":0,"Seats":1}):
      z=x["Seats"]
      print("Available seats :- ",z)
    req= int(input("Enter number of seats(one user cannot book more than 5 books) :- "))
    if req>5:
      print("One user cannotbook more than 5 seats")
      req= int(input("Enter number of seats:- "))
    seatnumbers=[]
    for x in range(req):
      seatnumbers.append(z-x)
    print(seatnumbers)
    seatss=seatnumbers
    seat.update_one({"Movie":e,"Show Time":"2-PM"},{"$inc":{"Seats":-req}})
    for x in seat.find({"Movie":e,"Show Time":"2-PM"},{"_id":0,"Seats":1}):
      z=x["Seats"]
      print("Available seats :- ",z)

  if y == "6-PM":
    showt=y
    for x in seat.find({"Movie":e,"Show Time":"6-PM"},{"_id":0,"Seats":1}):
      z=x["Seats"]
      print("Available seats :- ",z)
    req= int(input("Enter number of seats(one user cannot book more than 5 books) :- "))
    if req>5:
      print("One user cannotbook more than 5 seats")
      req= int(input("Enter number of seats:- "))
    seatnumbers=[]
    for x in range(req):
      seatnumbers.append(z-x)
    print(seatnumbers)
    seatss=seatnumbers
    seat.update_one({"Movie":e,"Show Time":"6-PM"},{"$inc":{"Seats":-req}})
    for x in seat.find({"Movie":e,"Show Time":"6-PM"},{"_id":0,"Seats":1}):
      z=x["Seats"]
      print("Available seats :- ",z)

  elif y == "9-PM":
    showt=y
    for x in seat.find({"Movie":e,"Show Time":"9-PM"},{"_id":0,"Seats":1}):
      z=x["Seats"]
      print("Available seats :- ",z)
    req= int(input("Enter number of seats(one user cannot book more than 5 books) :- "))
    if req>5:
      print("One user cannotbook more than 5 seats")
      req= int(input("Enter number of seats:- "))
    seatnumbers=[]
    for x in range(req):
      seatnumbers.append(z-x)
    print(seatnumbers)
    seatss=seatnumbers
    seat.update_one({"Movie":e,"Show Time":"9-PM"},{"$inc":{"Seats":-req}})
    for x in seat.find({"Movie":e,"Show Time":"9-PM"},{"_id":0,"Seats":1}):
      z=x["Seats"]
      print("Available seats :- ",z)

# %%
print("Welcome to Movie Ticket Booking")
print("Login/Signup to process movie ticket Booking")
a= input("Are you a registred customer\n if yes enter y else enter n - ")
lis=[]
emai=pa=p=0
if a=="n":
  
  newuser()
  phonenumber()
  fname=input("Enter first name :- ")
  Lname=input("Enter Last name :- ")
  name = fname+" "+Lname
  print(emai,p,pa,name)
  info={"Name":name,
        "Email-id": emai,
        "Phone Number":p,
        "Password": pa}
    
  records.insert_one(info)
  print("Registration Successful - Please login to book tickets")
  x=input("To login enter y :- ")
  if x=="y":
    email= input("Enter email-id :- ")
    existing(email)
    e=0
    sc=0
    movie()
    lis.append(e)
    lis.append(sc)
    seatss=0
    showt=0
    book()
    lis.append(seatss)
    lis.append(showt)

elif a=="y":
  emai=pa=p=0
  email= input("Enter email-id :- ")
  existing(email)
  e=0
  sc=0
  movie()
  lis.append(e)
  lis.append(sc)
  seatss=0
  showt=0
  book()
  lis.append(seatss)
  lis.append(showt)
  
print("       TICKET DETAILS")
import pandas as pd
import datetime
dt_now = datetime.datetime.now()
lis.append(dt_now)

y={"-":["Booking Email:","Name:","Movie name:","Screen:",'Seatnumbers:',"Show time:","Booking time:"]," ":lis}
z=pd.DataFrame(y,index=[1,2,3,4,5,6,7])
print(z)
import qrcode as qr
qr.make(z)
